# %%
# Importing standard packages for data exploration and processing.

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# This notebook is going to focus on processing the players' match statistics only. The other three files will be processed in separate notebooks.

# %%
# Unlike in the Stage 1 notebooks, we are going to create new variables rather than perform the operations in-place here.
# The reason is that we might need to review the original data during processing.

raw_players_match = pd.read_csv('../raw_data/raw_players_match.csv')

# %%
# Does everything seem to be alright with the data?

raw_players_match
# Out:
#                                      URL         Player name  IDSeason  \
# 0       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 1       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 2       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 3       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 4       https://en.khl.ru/players/16673/      Sergei Abramov       244
# ...                                  ...                 ...       ...
# 451101  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451102  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451103  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451104  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451105  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
#
#                           Season  Team         Date  \
# 0       Regular season 2013/2014    54  28 Dec 2013
# 1       Regular season 2013/2014    54   3 Jan 2014
# 2       Regular season 2013/2014    54   5 Jan 2014
# 3       Regular season 2013/2014    54   7 Jan 2014
# 4       Regular season 2013/2014    54   9 Jan 2014
# ...                          ...   ...          ...
# 451101  Regular season 2009/2010    56  13 Dec 2009
# 451102  Regular season 2009/2010    56  23 Dec 2009
# 451103  Regular season 2009/2010    56  25 Dec 2009
# 451104  Regular season 2009/2010    56  27 Dec 2009
# 451105  Regular season 2009/2010    56   7 Jan 2010
#
#                              Teams  Score   №  G  ...  BLS  FOA   W   L  SOP  \
# 0                     Barys - Amur    8:2  91  0  ...  NaN  NaN NaN NaN  NaN
# 1                 Amur - Lokomotiv    2:1  91  0  ...  NaN  NaN NaN NaN  NaN
# 2                       Amur - SKA    1:6  91  0  ...  NaN  NaN NaN NaN  NaN
# 3                    Amur - Atlant  2:3 Б  91  0  ...  NaN  NaN NaN NaN  NaN
# 4                 Amur - Severstal    1:3  91  0  ...  NaN  NaN NaN NaN  NaN
# ...                            ...    ...  .. ..  ...  ...  ...  ..  ..  ...
# 451101            Severstal - CSKA  4:3 Б  15  0  ...  NaN  NaN NaN NaN  NaN
# 451102           Barys - Severstal    3:4  15  0  ...  NaN  NaN NaN NaN  NaN
# 451103  Salavat Yulaev - Severstal    2:3  15  0  ...  NaN  NaN NaN NaN  NaN
# 451104        Avangard - Severstal    3:1  15  0  ...  NaN  NaN NaN NaN  NaN
# 451105          Severstal - HC MVD    1:3  15  0  ...  NaN  NaN NaN NaN  NaN
#
#         GA  Sv  %Sv  GAA  SO
# 0      NaN NaN  NaN  NaN NaN
# 1      NaN NaN  NaN  NaN NaN
# 2      NaN NaN  NaN  NaN NaN
# 3      NaN NaN  NaN  NaN NaN
# 4      NaN NaN  NaN  NaN NaN
# ...     ..  ..  ...  ...  ..
# 451101 NaN NaN  NaN  NaN NaN
# 451102 NaN NaN  NaN  NaN NaN
# 451103 NaN NaN  NaN  NaN NaN
# 451104 NaN NaN  NaN  NaN NaN
# 451105 NaN NaN  NaN  NaN NaN
#
# [451106 rows x 40 columns]

# %% [markdown]
# We can already see that there are some issues with missing data. In addition, the player's team is only indicated by an id rather than its official name.

# %%
# What would the summary tell us?

raw_players_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451106 entries, 0 to 451105
# Data columns (total 40 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   URL          451106 non-null  object
#  1   Player name  451106 non-null  object
#  2   IDSeason     451106 non-null  int64
#  3   Season       451106 non-null  object
#  4   Team         451106 non-null  int64
#  5   Date         451106 non-null  object
#  6   Teams        451106 non-null  object
#  7   Score        451106 non-null  object
#  8   №            451106 non-null  int64
#  9   G            451106 non-null  int64
#  10  Assists      451106 non-null  int64
#  11  PTS          409063 non-null  float64
#  12  +/-          409063 non-null  float64
#  13  +            409063 non-null  float64
#  14  -            409063 non-null  float64
#  15  PIM          451106 non-null  int64
#  16  ESG          409063 non-null  float64
#  17  PPG          409063 non-null  float64
#  18  SHG          409063 non-null  float64
#  19  OTG          409063 non-null  float64
#  20  GWG          409063 non-null  float64
#  21  SDS          409063 non-null  float64
#  22  SOG          451106 non-null  int64
#  23  %SOG         409063 non-null  object
#  24  FO           409063 non-null  float64
#  25  FOW          409063 non-null  float64
#  26  %FO          409063 non-null  object
#  27  TOI          451083 non-null  object
#  28  SFT          409063 non-null  object
#  29  HITS         236575 non-null  float64
#  30  BLS          236575 non-null  float64
#  31  FOA          236575 non-null  float64
#  32  W            42020 non-null   float64
#  33  L            42020 non-null   float64
#  34  SOP          42020 non-null   float64
#  35  GA           42020 non-null   float64
#  36  Sv           42020 non-null   float64
#  37  %Sv          42020 non-null   object
#  38  GAA          42020 non-null   object
#  39  SO           42020 non-null   float64
# dtypes: float64(21), int64(7), object(12)
# memory usage: 137.7+ MB

# %% [markdown]
# We can see that in many columns there is no missing data at all. Some columns are stored as floats while they should in fact be integers. At the same time, for other columns there is a clear separation into skaters (forwards and defencemen) and goalies.
#
# For example, we can see that season statistics appears to have 409063 rows of data for skaters and 42020 rows for goalies, with a total of 451083 rows. However, there are 451106 rows in the dataframe so 23 rows seem to be unaccounted in either.
#
# Let us find out who is messing up our data. We can see that icetime has exactly 451083 non-null values which is in line with our calculations, so we are probably interested in the cases when icetime is null.

# %%
# We need the rows for which both icetime are null.

raw_players_match[raw_players_match['TOI'].isnull()]
# Out:
#                                      URL        Player name  IDSeason  \
# 35442   https://en.khl.ru/players/33314/       Casey Bailey       671
# 46321   https://en.khl.ru/players/29144/     David Boldizar       468
# 46322   https://en.khl.ru/players/29144/     David Boldizar       468
# 46323   https://en.khl.ru/players/29144/     David Boldizar       468
# 46324   https://en.khl.ru/players/29144/     David Boldizar       468
# 46325   https://en.khl.ru/players/29144/     David Boldizar       468
# 46326   https://en.khl.ru/players/29144/     David Boldizar       468
# 46327   https://en.khl.ru/players/29144/     David Boldizar       671
# 46328   https://en.khl.ru/players/29144/     David Boldizar       671
# 46329   https://en.khl.ru/players/29144/     David Boldizar       671
# 46330   https://en.khl.ru/players/29144/     David Boldizar       671
# 46331   https://en.khl.ru/players/29144/     David Boldizar       671
# 46332   https://en.khl.ru/players/29144/     David Boldizar       671
# 46333   https://en.khl.ru/players/29144/     David Boldizar       671
# 46334   https://en.khl.ru/players/29144/     David Boldizar       671
# 46335   https://en.khl.ru/players/29144/     David Boldizar       671
# 46336   https://en.khl.ru/players/29144/     David Boldizar       671
# 126981  https://en.khl.ru/players/13952/  Alexander Islamov       202
# 132670  https://en.khl.ru/players/23657/      Ivan Jankovic       309
# 240654  https://en.khl.ru/players/23658/     Matija Milicic       309
# 246985   https://en.khl.ru/players/4457/    Ilya Malyushkin       185
# 354777  https://en.khl.ru/players/22774/        Derek Smith       405
# 354778  https://en.khl.ru/players/22774/        Derek Smith       405
#
#                           Season  Team         Date  \
# 35442   Regular season 2018/2019   246  20 Feb 2019
# 46321   Regular season 2017/2018   246  20 Sep 2017
# 46322   Regular season 2017/2018   246  23 Sep 2017
# 46323   Regular season 2017/2018   246  25 Sep 2017
# 46324   Regular season 2017/2018   246  27 Sep 2017
# 46325   Regular season 2017/2018   246   3 Oct 2017
# 46326   Regular season 2017/2018   246   5 Oct 2017
# 46327   Regular season 2018/2019   246  22 Jan 2019
# 46328   Regular season 2018/2019   246  24 Jan 2019
# 46329   Regular season 2018/2019   246  26 Jan 2019
# 46330   Regular season 2018/2019   246  31 Jan 2019
# 46331   Regular season 2018/2019   246   4 Feb 2019
# 46332   Regular season 2018/2019   246  11 Feb 2019
# 46333   Regular season 2018/2019   246  13 Feb 2019
# 46334   Regular season 2018/2019   246  15 Feb 2019
# 46335   Regular season 2018/2019   246  18 Feb 2019
# 46336   Regular season 2018/2019   246  20 Feb 2019
# 126981  Regular season 2011/2012    71  30 Dec 2011
# 132670  Regular season 2015/2016   419  18 Feb 2016
# 240654  Regular season 2015/2016   419  16 Feb 2016
# 246985  Regular season 2010/2011   213   7 Oct 2010
# 354777  Regular season 2016/2017   419   8 Oct 2016
# 354778  Regular season 2016/2017   419  10 Oct 2016
#
#                              Teams   Score   №  G  ...  BLS  FOA   W   L  SOP  \
# 35442             Jokerit - Slovan     7:1  25  0  ...  NaN  NaN NaN NaN  NaN
# 46321             Slovan - Ak Bars     3:6  23  0  ...  NaN  NaN NaN NaN  NaN
# 46322              Vityaz - Slovan     4:0  23  0  ...  NaN  NaN NaN NaN  NaN
# 46323                CSKA - Slovan     3:2  23  0  ...  NaN  NaN NaN NaN  NaN
# 46324              Slovan - Vityaz     4:3  23  0  ...  NaN  NaN NaN NaN  NaN
# 46325           Slovan - Severstal   5:4 Б  23  0  ...  NaN  NaN NaN NaN  NaN
# 46326             Slovan - Torpedo     0:1  23  0  ...  NaN  NaN NaN NaN  NaN
# 46327            Dinamo R - Slovan     3:2  61  0  ...  NaN  NaN NaN NaN  NaN
# 46328           Lokomotiv - Slovan     7:0  61  0  ...  NaN  NaN NaN NaN  NaN
# 46329           Slovan - Dinamo Mn     2:4  61  0  ...  NaN  NaN NaN NaN  NaN
# 46330            Slovan - HC Sochi  3:2 ОТ  61  0  ...  NaN  NaN NaN NaN  NaN
# 46331            Slovan - Dinamo R     2:1  61  0  ...  NaN  NaN NaN NaN  NaN
# 46332                Slovan - CSKA     1:4  61  0  ...  NaN  NaN NaN NaN  NaN
# 46333           Slovan - Dinamo Mn     3:2  61  0  ...  NaN  NaN NaN NaN  NaN
# 46334                CSKA - Slovan     4:1  61  0  ...  NaN  NaN NaN NaN  NaN
# 46335            Dinamo R - Slovan     5:0  61  0  ...  NaN  NaN NaN NaN  NaN
# 46336             Jokerit - Slovan     7:1  61  0  ...  NaN  NaN NaN NaN  NaN
# 126981  Metallurg Mg - Neftekhimik     1:0  11  0  ...  NaN  NaN NaN NaN  NaN
# 132670        HC Sochi - Medvescak     6:4  50  0  ...  NaN  NaN NaN NaN  NaN
# 240654       Lokomotiv - Medvescak     4:2  55  0  ...  NaN  NaN NaN NaN  NaN
# 246985         Ugra - Metallurg Mg   2:3 Б  35  0  ...  NaN  NaN NaN NaN  NaN
# 354777       Medvescak - Severstal     7:3  79  0  ...  NaN  NaN NaN NaN  NaN
# 354778    OHC Dynamo M - Medvescak     5:1  79  0  ...  NaN  NaN NaN NaN  NaN
#
#         GA  Sv  %Sv  GAA  SO
# 35442  NaN NaN  NaN  NaN NaN
# 46321  NaN NaN  NaN  NaN NaN
# 46322  NaN NaN  NaN  NaN NaN
# 46323  NaN NaN  NaN  NaN NaN
# 46324  NaN NaN  NaN  NaN NaN
# 46325  NaN NaN  NaN  NaN NaN
# 46326  NaN NaN  NaN  NaN NaN
# 46327  NaN NaN  NaN  NaN NaN
# 46328  NaN NaN  NaN  NaN NaN
# 46329  NaN NaN  NaN  NaN NaN
# 46330  NaN NaN  NaN  NaN NaN
# 46331  NaN NaN  NaN  NaN NaN
# 46332  NaN NaN  NaN  NaN NaN
# 46333  NaN NaN  NaN  NaN NaN
# 46334  NaN NaN  NaN  NaN NaN
# 46335  NaN NaN  NaN  NaN NaN
# 46336  NaN NaN  NaN  NaN NaN
# 126981 NaN NaN  NaN  NaN NaN
# 132670 NaN NaN  NaN  NaN NaN
# 240654 NaN NaN  NaN  NaN NaN
# 246985 NaN NaN  NaN  NaN NaN
# 354777 NaN NaN  NaN  NaN NaN
# 354778 NaN NaN  NaN  NaN NaN
#
# [23 rows x 40 columns]

# %% [markdown]
# We have multiple culprits here. Something must have went wrong with the way their data was stored.

# %%
raw_players_match[raw_players_match['TOI'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 35442 to 354778
# Data columns (total 40 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   URL          23 non-null     object
#  1   Player name  23 non-null     object
#  2   IDSeason     23 non-null     int64
#  3   Season       23 non-null     object
#  4   Team         23 non-null     int64
#  5   Date         23 non-null     object
#  6   Teams        23 non-null     object
#  7   Score        23 non-null     object
#  8   №            23 non-null     int64
#  9   G            23 non-null     int64
#  10  Assists      23 non-null     int64
#  11  PTS          0 non-null      float64
#  12  +/-          0 non-null      float64
#  13  +            0 non-null      float64
#  14  -            0 non-null      float64
#  15  PIM          23 non-null     int64
#  16  ESG          0 non-null      float64
#  17  PPG          0 non-null      float64
#  18  SHG          0 non-null      float64
#  19  OTG          0 non-null      float64
#  20  GWG          0 non-null      float64
#  21  SDS          0 non-null      float64
#  22  SOG          23 non-null     int64
#  23  %SOG         0 non-null      object
#  24  FO           0 non-null      float64
#  25  FOW          0 non-null      float64
#  26  %FO          0 non-null      object
#  27  TOI          0 non-null      object
#  28  SFT          0 non-null      object
#  29  HITS         0 non-null      float64
#  30  BLS          0 non-null      float64
#  31  FOA          0 non-null      float64
#  32  W            0 non-null      float64
#  33  L            0 non-null      float64
#  34  SOP          0 non-null      float64
#  35  GA           0 non-null      float64
#  36  Sv           0 non-null      float64
#  37  %Sv          0 non-null      object
#  38  GAA          0 non-null      object
#  39  SO           0 non-null      float64
# dtypes: float64(21), int64(7), object(12)
# memory usage: 7.4+ KB

# %% [markdown]
# Most of the data is missing, and not because it is supposed to be a zero. After all, icetime cannot be zero if a player has participated in a match. And the only values present are integers, so definitely something weird with the formatting.
#
# We do not know whether the player has zeroes in all those columns or if it is just a data storage issue. Since those are only a few broken rows, let us just drop them altogether.

# %%
players_match = raw_players_match[~raw_players_match['TOI'].isnull()]

# Cleaning up the dataframe.

players_match = players_match.reset_index(drop=True)

# %% [markdown]
# Now we can create a new column indicating whether a player is a skater or a goalie. Let us use the shifts for separation.

# %%
# Number of shifts on ice is only tracked for skaters, so goalies are supposed to have it as null.

players_match['Role'] = np.where(players_match['SFT'].isnull(), 'Goalie', 'Skater')
# Out:
# <ipython-input-9-a06909d7e3dd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_match['Role'] = np.where(players_match['SFT'].isnull(), 'Goalie', 'Skater')

# %%
players_match
# Out:
#                                      URL         Player name  IDSeason  \
# 0       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 1       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 2       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 3       https://en.khl.ru/players/16673/      Sergei Abramov       244
# 4       https://en.khl.ru/players/16673/      Sergei Abramov       244
# ...                                  ...                 ...       ...
# 451078  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451079  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451080  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451081  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
# 451082  https://en.khl.ru/players/11543/  Alexander Zevakhin       167
#
#                           Season  Team         Date  \
# 0       Regular season 2013/2014    54  28 Dec 2013
# 1       Regular season 2013/2014    54   3 Jan 2014
# 2       Regular season 2013/2014    54   5 Jan 2014
# 3       Regular season 2013/2014    54   7 Jan 2014
# 4       Regular season 2013/2014    54   9 Jan 2014
# ...                          ...   ...          ...
# 451078  Regular season 2009/2010    56  13 Dec 2009
# 451079  Regular season 2009/2010    56  23 Dec 2009
# 451080  Regular season 2009/2010    56  25 Dec 2009
# 451081  Regular season 2009/2010    56  27 Dec 2009
# 451082  Regular season 2009/2010    56   7 Jan 2010
#
#                              Teams  Score   №  G  ...  FOA   W   L  SOP  GA  \
# 0                     Barys - Amur    8:2  91  0  ...  NaN NaN NaN  NaN NaN
# 1                 Amur - Lokomotiv    2:1  91  0  ...  NaN NaN NaN  NaN NaN
# 2                       Amur - SKA    1:6  91  0  ...  NaN NaN NaN  NaN NaN
# 3                    Amur - Atlant  2:3 Б  91  0  ...  NaN NaN NaN  NaN NaN
# 4                 Amur - Severstal    1:3  91  0  ...  NaN NaN NaN  NaN NaN
# ...                            ...    ...  .. ..  ...  ...  ..  ..  ...  ..
# 451078            Severstal - CSKA  4:3 Б  15  0  ...  NaN NaN NaN  NaN NaN
# 451079           Barys - Severstal    3:4  15  0  ...  NaN NaN NaN  NaN NaN
# 451080  Salavat Yulaev - Severstal    2:3  15  0  ...  NaN NaN NaN  NaN NaN
# 451081        Avangard - Severstal    3:1  15  0  ...  NaN NaN NaN  NaN NaN
# 451082          Severstal - HC MVD    1:3  15  0  ...  NaN NaN NaN  NaN NaN
#
#         Sv  %Sv  GAA  SO    Role
# 0      NaN  NaN  NaN NaN  Skater
# 1      NaN  NaN  NaN NaN  Skater
# 2      NaN  NaN  NaN NaN  Skater
# 3      NaN  NaN  NaN NaN  Skater
# 4      NaN  NaN  NaN NaN  Skater
# ...     ..  ...  ...  ..     ...
# 451078 NaN  NaN  NaN NaN  Skater
# 451079 NaN  NaN  NaN NaN  Skater
# 451080 NaN  NaN  NaN NaN  Skater
# 451081 NaN  NaN  NaN NaN  Skater
# 451082 NaN  NaN  NaN NaN  Skater
#
# [451083 rows x 41 columns]

# %% [markdown]
# We have quite a bit of work ahead of us. Many columns contain data that we would like to see in other columns, such as years, home/visit team and whether the game was finished in the main time or in overtime/by shootouts.

# %%
# We do not really need the 'IDSeason' column, as the current 'Season' column is indicative enough.

players_match = players_match.drop('IDSeason', axis=1)

# Separating the 'Season' column into the type of season and the years would allow us to more easily sort it.

players_match['Year'] = players_match['Season'].apply(lambda x: x[:-10])
players_match['Season'] = players_match['Season'].apply(lambda x: x[-9:])

# We need to separate the teams into two columns.
# It is important to remove the trailling spaces from the results.

players_match['Home_team'] = players_match['Teams'].apply(lambda x: x.split('-')[0].strip())
players_match['Away_team'] = players_match['Teams'].apply(lambda x: x.split('-')[1].strip())

# Now separating the match score into each team's corresponding score.
# In addition, we will create a 'Length' column that will indicate in which period the game has ended.
# The split on a space separates the scores from an overtime indicator, and the split on a colon separates teams' scores.

players_match['Home_score'] = players_match['Score'].apply(lambda x: x.split(' ')[0].split(':')[0])
players_match['Away_score'] = players_match['Score'].apply(lambda x: x.split(' ')[0].split(':')[1])

# We cannot just take the second element after the split since the list will only contain 1 element if there is no overtime.
# But we can artificially create an extra element of a list by padding the string with an extra space at the end.
# This trick allows us to take the overtime indicator if it is present or a blank string if it is not.

players_match['Length'] = players_match['Score'].apply(lambda x: (x + ' ').split(' ')[1])

# %%
# What values do we have here?

players_match['Length'].unique()
# Out:
# array(['', 'Б', 'ОТ'], dtype=object)

# %% [markdown]
# We could previously see a Russian letter 'Б' in the 'Score' column. It indicates shootouts and was not properly changed to English it seems. Therefore, we need to change it and, while we are at it, might as well change all values to the more obvious ones.

# %%
length_dict = {'': 'Standard', 'ОТ': 'Overtime', 'Б': 'Shootouts'}

players_match['Length'] = players_match['Length'].map(length_dict)

# %% [markdown]
# We can now rearrange the columns.

# %%
# Dropping the columns we are no longer interested in.

players_match.drop(['Teams', 'Score'], axis=1, inplace=True)

# We will have to move the columns around quite a bit.

columns = players_match.columns

players_match = players_match[[col for col in columns[:2]] + ['Role', 'Year'] + [col for col in columns[2:5]] +
                              ['Home_team', 'Away_team', 'Home_score', 'Away_score','Length'] + [col for col in columns[5:-7]]]

# The current column names are not very informative, are they?

header = ['Profile', 'Player', 'Role', 'Year', 'Season', 'Team_id', 'Date', 'Home_team', 'Away_team', 'Home_score',
          'Away_score', 'Length', 'Number', 'Goals', 'Assists', 'Points', 'Plus_minus', 'Plus', 'Minus',
          'Penalties', 'Goals_even', 'Goals_powerplay', 'Goals_shorthanded', 'Goals_overtime', 'Game_winning_goals',
          'Game_winning_shootouts', 'Shots', 'Shots_percentage', 'Faceoffs', 'Faceoffs_won', 'Faceoffs_percentage',
          'Icetime','Hits', 'Shots_blocked', 'Penalties_against', 'Wins', 'Losses', 'Shootouts', 'Goals_against',
          'Saves', 'Saves_percentage', 'Goals_against_average', 'Shutouts']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-7fb80ca3f768> in <module>
#       1 # Dropping the columns we are no longer interested in.
#       2
# ----> 3 players_match.drop(['Teams', 'Score'], axis=1, inplace=True)
#       4
#       5 # We will have to move the columns around quite a bit.
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Teams' 'Score'] not found in axis"

# %%
players_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451083 entries, 0 to 451082
# Data columns (total 44 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   URL          451083 non-null  object
#  1   Player name  451083 non-null  object
#  2   Role         451083 non-null  object
#  3   Year         451083 non-null  object
#  4   Season       451083 non-null  object
#  5   Team         451083 non-null  int64
#  6   Date         451083 non-null  object
#  7   Home_team    451083 non-null  object
#  8   Away_team    451083 non-null  object
#  9   Home_score   451083 non-null  object
#  10  Away_score   451083 non-null  object
#  11  Length       451083 non-null  object
#  12  №            451083 non-null  int64
#  13  G            451083 non-null  int64
#  14  Assists      451083 non-null  int64
#  15  PTS          409063 non-null  float64
#  16  +/-          409063 non-null  float64
#  17  +            409063 non-null  float64
#  18  -            409063 non-null  float64
#  19  PIM          451083 non-null  int64
#  20  ESG          409063 non-null  float64
#  21  PPG          409063 non-null  float64
#  22  SHG          409063 non-null  float64
#  23  OTG          409063 non-null  float64
#  24  GWG          409063 non-null  float64
#  25  SDS          409063 non-null  float64
#  26  SOG          451083 non-null  int64
#  27  %SOG         409063 non-null  object
#  28  FO           409063 non-null  float64
#  29  FOW          409063 non-null  float64
#  30  %FO          409063 non-null  object
#  31  TOI          451083 non-null  object
#  32  SFT          409063 non-null  object
#  33  HITS         236575 non-null  float64
#  34  BLS          236575 non-null  float64
#  35  FOA          236575 non-null  float64
#  36  W            42020 non-null   float64
#  37  L            42020 non-null   float64
#  38  SOP          42020 non-null   float64
#  39  GA           42020 non-null   float64
#  40  Sv           42020 non-null   float64
#  41  %Sv          42020 non-null   object
#  42  GAA          42020 non-null   object
#  43  SO           42020 non-null   float64
# dtypes: float64(21), int64(6), object(17)
# memory usage: 151.4+ MB

# %%
header = ['Profile', 'Player', 'Role', 'Year', 'Season', 'Team_id', 'Date', 'Home_team', 'Away_team', 'Home_score',
          'Away_score', 'Length', 'Number', 'Goals', 'Assists', 'Points', 'Plus_minus', 'Plus', 'Minus',
          'Penalties', 'Goals_even', 'Goals_powerplay', 'Goals_shorthanded', 'Goals_overtime', 'Game_winning_goals',
          'Game_winning_shootouts', 'Shots', 'Shots_percentage', 'Faceoffs', 'Faceoffs_won', 'Faceoffs_percentage',
          'Icetime','Hits', 'Shots_blocked', 'Penalties_against', 'Wins', 'Losses', 'Shootouts', 'Goals_against',
          'Saves', 'Saves_percentage', 'Goals_against_average', 'Shutouts']

players_match.columns = header
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-b9bb27d18b24> in <module>
#       6           'Saves', 'Saves_percentage', 'Goals_against_average', 'Shutouts']
#       7
# ----> 8 players_match.columns = header
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# C:\Work\Software\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 44 elements, new values have 43 elements

# %%
players_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451083 entries, 0 to 451082
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Profile                 451083 non-null  object
#  1   Player                  451083 non-null  object
#  2   Role                    451083 non-null  object
#  3   Year                    451083 non-null  object
#  4   Season                  451083 non-null  object
#  5   Team_id                 451083 non-null  int64
#  6   Date                    451083 non-null  object
#  7   Home_team               451083 non-null  object
#  8   Away_team               451083 non-null  object
#  9   Home_score              451083 non-null  object
#  10  Away_score              451083 non-null  object
#  11  Length                  451083 non-null  object
#  12  Number                  451083 non-null  int64
#  13  Games                   451083 non-null  int64
#  14  Goals                   451083 non-null  int64
#  15  Assists                 409063 non-null  float64
#  16  Points                  409063 non-null  float64
#  17  Plus_minus              409063 non-null  float64
#  18  Plus                    409063 non-null  float64
#  19  Minus                   451083 non-null  int64
#  20  Penalties               409063 non-null  float64
#  21  Goals_even              409063 non-null  float64
#  22  Goals_powerplay         409063 non-null  float64
#  23  Goals_shorthanded       409063 non-null  float64
#  24  Goals_overtime          409063 non-null  float64
#  25  Game_winning_goals      409063 non-null  float64
#  26  Game_winning_shootouts  451083 non-null  int64
#  27  Shots                   409063 non-null  object
#  28  Shots_percentage        409063 non-null  float64
#  29  Faceoffs                409063 non-null  float64
#  30  Faceoffs_won            409063 non-null  object
#  31  Faceoffs_percentage     451083 non-null  object
#  32  Icetime                 409063 non-null  object
#  33  Hits                    236575 non-null  float64
#  34  Shots_blocked           236575 non-null  float64
#  35  Penalties_against       236575 non-null  float64
#  36  Wins                    42020 non-null   float64
#  37  Losses                  42020 non-null   float64
#  38  Shootouts               42020 non-null   float64
#  39  Goals_against           42020 non-null   float64
#  40  Saves                   42020 non-null   float64
#  41  Saves_percentage        42020 non-null   object
#  42  Goals_against_average   42020 non-null   object
#  43  Shutouts                42020 non-null   float64
# dtypes: float64(21), int64(6), object(17)
# memory usage: 151.4+ MB

# %%
players_match.loc[0]
# Out:
# Profile                   https://en.khl.ru/players/16673/
# Player                                      Sergei Abramov
# Role                                                Skater
# Year                                        Regular season
# Season                                           2013/2014
# Team_id                                                 54
# Date                                           28 Dec 2013
# Home_team                                            Barys
# Away_team                                             Amur
# Home_score                                               8
# Away_score                                               2
# Length                                            Standard
# Number                                                  91
# Games                                                    0
# Goals                                                    0
# Assists                                                0.0
# Points                                                 0.0
# Plus_minus                                             0.0
# Plus                                                   0.0
# Minus                                                    0
# Penalties                                              0.0
# Goals_even                                             0.0
# Goals_powerplay                                        0.0
# Goals_shorthanded                                      0.0
# Goals_overtime                                         0.0
# Game_winning_goals                                     0.0
# Game_winning_shootouts                                   1
# Shots                                                  0.0
# Shots_percentage                                       0.0
# Faceoffs                                               0.0
# Faceoffs_won                                             -
# Faceoffs_percentage                                   8:02
# Icetime                                               12.0
# Hits                                                   NaN
# Shots_blocked                                          NaN
# Penalties_against                                      NaN
# Wins                                                   NaN
# Losses                                                 NaN
# Shootouts                                              NaN
# Goals_against                                          NaN
# Saves                                                  NaN
# Saves_percentage                                       NaN
# Goals_against_average                                  NaN
# Shutouts                                               NaN
# Name: 0, dtype: object
